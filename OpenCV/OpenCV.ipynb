# %%
import cv2

# %%
# Read an Image

img = cv2.imread('flower.JPG')

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #change color from BGR to RGB

# %%
plt.imshow(newImg)
